# %%
import pandas as pd
import sklearn
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import datetime
# %matplotlib inline
import seaborn as sns
sns.set(style="darkgrid")

# %%
data = pd.read_csv("../data/viz.csv")
data.head()
# Out:
#    Year   Jan   Feb   Mar   Apr    May    Jun    Jul    Aug    Sep    Oct  \
# 0  1880 -0.29 -0.18 -0.11 -0.20  -0.12  -0.23  -0.21  -0.09  -0.16  -0.23
# 1  1881 -0.15 -0.17  0.04  0.04   0.02   -0.2  -0.07  -0.02  -0.14   -0.2
# 2  1882  0.14  0.15  0.04 -0.19  -0.16  -0.26  -0.21  -0.05   -0.1  -0.25
# 3  1883 -0.31 -0.39 -0.13 -0.17   -0.2  -0.13  -0.08  -0.15  -0.21  -0.14
# 4  1884 -0.15 -0.08 -0.37 -0.43  -0.37  -0.41  -0.35  -0.26  -0.27  -0.24
#
#      Nov    Dec    J-D    D-N    DJF    MAM    JJA    SON
# 0   -0.2  -0.23  -0.19    ***    ***  -0.14  -0.18   -0.2
# 1  -0.22  -0.11   -0.1  -0.11  -0.18   0.03   -0.1  -0.19
# 2  -0.16  -0.24  -0.11   -0.1   0.06   -0.1  -0.17  -0.17
# 3  -0.22  -0.16  -0.19   -0.2  -0.32  -0.17  -0.12  -0.19
# 4   -0.3  -0.29  -0.29  -0.28  -0.13  -0.39  -0.34  -0.27

# %%
ax = sns.lineplot(x="Year", y="Jan", label="January", data=data)
ax.set(xlabel='Year', ylabel='Celsia')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-0accbb043c0a> in <module>
# ----> 1 sns.lmplot(x=data["Year"], y=data["Jan"], data=data);
#
# ~/projects/ml-showcase/env/lib/python3.7/site-packages/seaborn/regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     549     need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     550     cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 551     data = data[cols]
#     552
#     553     # Initialize the grid
#
# ...
